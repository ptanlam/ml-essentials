# %%
import pandas as pd

# %%
insurance_data = pd.read_csv('processed_dataset/insurance_processed.csv')

insurance_data.sample(10)
# Out:
#       age     bmi  children  region      charges  sex_female  sex_male  \
# 1097   22  33.770         0       2   1674.63230           0         1
# 972    22  20.235         0       1   2527.81865           1         0
# 153    42  23.370         0       0  19964.74630           1         0
# 416    52  34.100         0       2   9140.95100           0         1
# 756    39  22.800         3       0   7985.81500           1         0
# 60     43  27.360         3       0   8606.21740           0         1
# 279    51  21.560         1       2   9855.13140           1         0
# 236    18  26.730         0       2   1615.76670           1         0
# 66     61  39.100         2       3  14235.07200           1         0
# 1022   47  36.080         1       2  42211.13820           0         1
#
#       smoker_no  smoker_yes
# 1097          1           0
# 972           1           0
# 153           0           1
# 416           1           0
# 756           1           0
# 60            1           0
# 279           1           0
# 236           1           0
# 66            1           0
# 1022          0           1

# %%
X = insurance_data.drop('charges', axis=1)

Y = insurance_data['charges']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree_reg1 = DecisionTreeRegressor(max_depth=1)
tree_reg1.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
y2 = y_train - tree_reg1.predict(x_train)

# %%
tree_reg2 = DecisionTreeRegressor(max_depth=3)
tree_reg2.fit(x_train, y2)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
y3 = y2 - tree_reg2.predict(x_train)

# %%
tree_reg3 = DecisionTreeRegressor(max_depth=3)
tree_reg3.fit(x_train, y3)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
y_pred = sum(tree.predict(x_test) for tree in (tree_reg1, tree_reg2, tree_reg3))

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.8400685096792355

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor(max_depth=3, n_estimators=3, learning_rate=1.0)

gbr.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(learning_rate=1.0, n_estimators=3)

# %%
y_pred = gbr.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.8511567279575301
